# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv('customers.csv')
orders = pd.read_csv('orders.csv')
order_items = pd.read_csv('order_items.csv')

# %%
customers.sort_values('last_name').head()
# Out:
#      customer_id first_name last_name      city
# 31          1032       Noah     Brown        LA
# 112         1113      Maria     Brown       NYC
# 97          1098        Zoe      Chen        LA
# 53          1054        Zoe     Davis  New York
# 32          1033       alex     Davis   chicago

# %%
orders.sort_values('order_date', ascending=False)
# Out:
#      order_id  customer_id  order_date
# 213      5214         1075  2024-03-31
# 383      5384         1111  2024-03-31
# 215      5216         1103  2024-03-31
# 207      5208         1023  2024-03-30
# 14       5015         1019  2024-03-30
# ..        ...          ...         ...
# 430      5431         1006  2024-01-01
# 271      5272         1004  2024-01-01
# 56       5057         1019  2024-01-01
# 13       5014         1090  2024-01-01
# 246      5247         1017  2024-01-01
#
# [450 rows x 3 columns]

# %%
ny_customers = customers[customers['city'].str.lower().isin(['new york', 'nyc'])]
ny_customers.head()
# Out:
#     customer_id first_name last_name      city
# 0          1001       Evan     Smith  New York
# 3          1004      Aisha     Smith  new york
# 5          1006       Evan     Patel  new york
# 7          1008      Maria     Smith       NYC
# 10         1011        Ben     Davis  New York

# %%
recent_orders = orders[orders['order_date'] > '2024-02-14']
recent_orders.head()
# Out:
#     order_id  customer_id  order_date
# 1       5002         1045  2024-02-20
# 5       5006         1031  2024-03-10
# 7       5008         1061  2024-03-08
# 9       5010         1054  2024-03-24
# 12      5013         1074  2024-02-16

# %%
order_items[order_items['quantity'] >= 2].sort_values
# Out:
# <bound method DataFrame.sort_values of      order_id product_name  quantity  unit_price
# 0        5311      Monitor         3         300
# 1        5303     Keyboard         3          70
# 2        5012     Keyboard         3          70
# 3        5318      Monitor         3         300
# 6        5339    Desk Lamp         2          45
# ..        ...          ...       ...         ...
# 891      5021    Desk Lamp         2          45
# 893      5107      Monitor         3         300
# 895      5303    USB Cable         2          10
# 896      5117      Monitor         2         300
# 898      5399    USB Cable         2          10
#
# [464 rows x 4 columns]>

# %%
customers['first_name '] = customers['first_name'].str.strip().str.capitalize()
customers['last_name '] = customers['last_name'].str.strip().str.capitalize()

# %%
customers['city'].value_counts()
# Out:
# city
# LA             24
# New York       22
# chicago        17
# Los Angeles    17
# new york       15
# NYC            15
# Chicago        10
# Name: count, dtype: int64

# %%
city_stand_map = {'LA' : 'Los Angeles', 'NYC' : 'New York'}

# %%
customers['city'] = customers['city'].replace(city_stand_map)

# %%
customers['city'] = customers['city'].str.title()

# %%
customers['clean_last_name'] = customers['last_name'].apply(
    lambda x:
    x.strip()
)

# %%
customers['clean_last_name'].value_counts()
# Out:
# clean_last_name
# Davis       19
# Smith       18
# Patel       17
# Brown       16
# Chen        16
# Anderson    13
# Wilson      13
# Lopez        8
# Name: count, dtype: int64

# %% [markdown]
# # Merging Tables

# %%
orders_with_customers = orders.merge(customers, how='inner')
orders_with_customers.head()
# Out:
#    order_id  customer_id  order_date first_name last_name         city  \
# 0      5001         1089  2024-01-26      Aisha     Smith     New York
# 1      5002         1045  2024-02-20      Priya     Davis     New York
# 2      5003         1004  2024-02-14      Aisha     Smith     New York
# 3      5004         1036  2024-02-13      Chloe     Davis     New York
# 4      5005         1070  2024-01-05     jordan     Brown  Los Angeles
#
#   first_name  last_name  clean_last_name
# 0       Aisha      Smith           Smith
# 1       Priya      Davis           Davis
# 2       Aisha      Smith           Smith
# 3       Chloe      Davis           Davis
# 4      Jordan      Brown           Brown

# %%
orders_customers_items = orders_with_customers.merge(order_items, on = 'order_id', how= 'inner')
orders_customers_items.head()
# Out:
#    order_id  customer_id  order_date first_name last_name      city  \
# 0      5001         1089  2024-01-26      Aisha     Smith  New York
# 1      5001         1089  2024-01-26      Aisha     Smith  New York
# 2      5001         1089  2024-01-26      Aisha     Smith  New York
# 3      5002         1045  2024-02-20      Priya     Davis  New York
# 4      5002         1045  2024-02-20      Priya     Davis  New York
#
#   first_name  last_name  clean_last_name product_name  quantity  unit_price
# 0       Aisha      Smith           Smith      Monitor         1         300
# 1       Aisha      Smith           Smith    Desk Lamp         2          45
# 2       Aisha      Smith           Smith    Desk Lamp         1          45
# 3       Priya      Davis           Davis      Monitor         2         300
# 4       Priya      Davis           Davis      Monitor         2         300

# %%
combined = (
    orders.merge(customers, on='customer_id', how='inner').merge(order_items, on='order_id', how='inner')
)
combined.head()
# Out:
#    order_id  customer_id  order_date first_name last_name      city  \
# 0      5001         1089  2024-01-26      Aisha     Smith  New York
# 1      5001         1089  2024-01-26      Aisha     Smith  New York
# 2      5001         1089  2024-01-26      Aisha     Smith  New York
# 3      5002         1045  2024-02-20      Priya     Davis  New York
# 4      5002         1045  2024-02-20      Priya     Davis  New York
#
#   first_name  last_name  clean_last_name product_name  quantity  unit_price
# 0       Aisha      Smith           Smith      Monitor         1         300
# 1       Aisha      Smith           Smith    Desk Lamp         2          45
# 2       Aisha      Smith           Smith    Desk Lamp         1          45
# 3       Priya      Davis           Davis      Monitor         2         300
# 4       Priya      Davis           Davis      Monitor         2         300

# %% [markdown]
# Grouping and Aggregation

# %%
order_items['total_price'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 order_items['total_price'].sum()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'total_price'

# %%
order_items.groupby('product_name')['total_price'].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 order_items.groupby('product_name')['total_price'].sum().sort_values(ascending=False)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
#     246     ndim = self.obj[key].ndim
#     247     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: total_price'

# %%
order_items.groupby('product_name')['quantity'].sum().sort_values(ascending=False)
# Out:
# product_name
# Monitor      300
# Mouse        270
# USB Cable    257
# Laptop       247
# Desk Lamp    239
# Keyboard     202
# Name: quantity, dtype: int64

# %%
order_items.groupby('product_name').agg(
    total_revenue=('total_price', 'sum'),
    avg_quantity=('quantity', 'mean')
)
# Out:
#   Cell In[41], line 2
#     total_revenue=('total_price', 'sum')
#                   ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
combined.groupby('customer_id')['total_price'].sum().head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 combined.groupby('customer_id')['total_price'].sum().head()
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\base.py:245, in SelectionMixin.__getitem__(self, key)
#     243 else:
#     244     if key not in self.obj:
# --> 245         raise KeyError(f"Column not found: {key}")
#     246     ndim = self.obj[key].ndim
#     247     return self._gotitem(key, ndim=ndim)
#
# KeyError: 'Column not found: total_price'

# %%
sample = combined[['customer_id', 'product_name', 'total_price']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 sample = combined[['customer_id', 'product_name', 'total_price']]
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['total_price'] not in index"

# %%
pivot = sample.pivot_table(index='customer_id',  columns = "product_name",
                            values="total_price", aggfunc="sum")

# %%
combined.query('quantity >= 2').groupby('city').agg(total_revenue=('total_price', 'sum')).sort_values('total_value', ascending=False)
