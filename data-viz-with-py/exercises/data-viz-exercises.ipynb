# %% [markdown]
# ## Exercises: Data Visualizations in Python
#
# We will be using [this dataset](https://www.kaggle.com/datasets/arnavvvvv/spotify-music/data) from Kaggle on Top Spotify Songs. No need to dowload it, it is already in the `exercises` directory.

# %% [markdown]
# ### Setting Up Your Data
#
# Before you dive into data visualizations, you need to set up your dataframe and make sure that it is cleaned and ready to go.

# %%
# import all librarys and modules needed
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from matplotlib import style

df = pd.read_csv("./Popular_Spotify_Songs.csv", encoding='latin-1')

df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# 25%              875.000000           0.000000           13.000000
# 50%             2224.000000           3.000000           34.000000
# 75%             5542.000000          16.000000           88.000000
# max            52898.000000         147.000000          672.000000
#
#        in_apple_charts  in_deezer_charts         bpm  danceability_%  \
# count       953.000000        953.000000  953.000000       953.00000
# mean         51.908709          2.666317  122.540399        66.96957
# std          50.630241          6.035599   28.057802        14.63061
# min           0.000000          0.000000   65.000000        23.00000
# 25%           7.000000          0.000000  100.000000        57.00000
# 50%          38.000000          0.000000  121.000000        69.00000
# 75%          87.000000          2.000000  140.000000        78.00000
# max         275.000000         58.000000  206.000000        96.00000
#
#         valence_%    energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# count  953.000000  953.000000      953.000000          953.000000  953.000000
# mean    51.431270   64.279119       27.057712            1.581322   18.213012
# std     23.480632   16.550526       25.996077            8.409800   13.711223
# min      4.000000    9.000000        0.000000            0.000000    3.000000
# 25%     32.000000   53.000000        6.000000            0.000000   10.000000
# 50%     51.000000   66.000000       18.000000            0.000000   12.000000
# 75%     70.000000   77.000000       43.000000            0.000000   24.000000
# max     97.000000   97.000000       97.000000           91.000000   97.000000
#
#        speechiness_%
# count     953.000000
# mean       10.131165
# std         9.912888
# min         2.000000
# 25%         4.000000
# 50%         6.000000
# 75%        11.000000
# max        64.000000

# %%
# import and clean data
df.value_counts()
# Out:
# track_name                    artist(s)_name       artist_count  released_year  released_month  released_day  in_spotify_playlists  in_spotify_charts  streams     in_apple_playlists  in_apple_charts  in_deezer_playlists  in_deezer_charts  in_shazam_charts  bpm  key  mode   danceability_%  valence_%  energy_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# 'Till I Collapse              Eminem, Nate Dogg    2             2002           5               26            22923                 0                  1695712020  78                  46               2,515                1                 0                 171  C#   Major  55              10         85        7               0                   8           20               1
# (It Goes Like) Nanana - Edit  Peggy Gou            1             2023           6               15            2259                  59                 57876440    0                   0                109                  17                0                 130  G    Minor  67              96         88        12              19                  8           4                1
# 10 Things I Hate About You    Leah Kate            1             2022           3               23            1301                  0                  185550869   23                  1                15                   0                 0                 154  G#   Major  54              45         79        1               0                   17          5                1
# 10:35                         Tiï¿½ï¿½sto, Tate M  2             2022           11              1             4942                  26                 325592432   190                 104              147                  18                63                120  G#   Major  70              70         79        7               0                   18          10               1
# 2 Be Loved (Am I Ready)       Lizzo                1             2022           7               14            3682                  6                  247689123   41                  0                158                  2                 68                156  G    Major  72              92         77        9               0                   8           11               1
#                                                                                                                                                                                                                                                                                                                                                                                        ..
# we fell in love in october    girl in red          1             2018           11              21            6858                  0                  723043854   31                  21               15                   0                 4                 130  G    Major  57              24         37        11              18                  16          3                1
# you broke me first            Tate McRae           1             2020           4               17            6638                  0                  1180094974  167                 19               318                  0                 1                 124  E    Major  64              8          37        79              0                   9           5                1
# ýýý98 Braves                  Morgan Wallen        1             2023           3               3             282                   0                  56533272    6                   15               0                    0                 0                 142  D    Major  49              48         67        10              0                   26          3                1
# ýýýýýýýýýýýý                  YOASOBI              1             2023           4               12            356                   16                 143573775   35                  102              8                    1                 117               166  C#   Major  57              84         94        11              0                   37          9                1
# ýýýýýýýýýýýýýýýýýýýýý         Fujii Kaze           1             2020           5               20            685                   14                 403097450   24                  94               9                    0                 23                158  F#   Minor  60              52         76        17              0                   19          5                1
# Name: count, Length: 817, dtype: int64

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %%
df['artist(s)_name'].value_counts()
# Out:
# artist(s)_name
# Taylor Swift                   34
# The Weeknd                     22
# Bad Bunny                      19
# SZA                            19
# Harry Styles                   17
#                                ..
# Ludwig Goransson, Foudeqush     1
# Jin                             1
# Selena Gomez                    1
# Feid, Paulo Londra              1
# Shae Gill, Ali Sethi            1
# Name: count, Length: 645, dtype: int64

# %%
df['track_name'].value_counts(dropna=False)
# Out:
# track_name
# Flowers                                   2
# Daylight                                  2
# Let It Snow! Let It Snow! Let It Snow!    2
# Die For You                               2
# Miss You                                  2
#                                          ..
# My Mind & Me                              1
# Bigger Than The Whole Sky                 1
# A Veces (feat. Feid)                      1
# En La De Ella                             1
# vampire                                   1
# Name: count, Length: 943, dtype: int64

# %%
df['track_name'].str.strip().str.title()
# Out:
# 0      Seven (Feat. Latto) (Explicit Ver.)
# 1                                     Lala
# 2                                  Vampire
# 3                             Cruel Summer
# 4                           Where She Goes
#                       ...
# 948                           My Mind & Me
# 949              Bigger Than The Whole Sky
# 950                   A Veces (Feat. Feid)
# 951                          En La De Ella
# 952                                  Alone
# Name: track_name, Length: 953, dtype: object

# %% [markdown]
# ### Creating Visualizations
#
# Now that the data is ready, you can use the dataset to create a number of different visualizations. You do not need to make the visualizations perfect; this is just for practice.
#
# #### Line Chart

# %%
# Single line chart
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
yearly = df.groupby('released_year')['streams'].mean()
plt.plot(yearly.index, yearly.values)

# %%
# Multiple Line chart

# %% [markdown]
# #### Bar Chart

# %%
# Vertical bar chart
plt.bar(yearly.index, yearly.values)
# Out:
# <BarContainer object of 50 artists>

# %%
# Horizontal bar chart

# %%
# Grouped bar chart

# %% [markdown]
# #### Scatter Plot

# %%
# scatter plot
ts_df = df[df['artist(s)_name'] == 'Taylor Swift']
ts_df.head()
# Out:
#                                            track_name artist(s)_name  \
# 3                                        Cruel Summer   Taylor Swift
# 21  I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...   Taylor Swift
# 33                                          Anti-Hero   Taylor Swift
# 37                                        Blank Space   Taylor Swift
# 38                                              Style   Taylor Swift
#
#     artist_count  released_year  released_month  released_day  \
# 3              1           2019               8            23
# 21             1           2023               7             7
# 33             1           2022              10            21
# 37             1           2014               1             1
# 38             1           2014               1             1
#
#     in_spotify_playlists  in_spotify_charts       streams  in_apple_playlists  \
# 3                   7858                100  8.008408e+08                 116
# 21                   516                 38  5.213525e+07                  73
# 33                  9082                 56  9.997483e+08                 242
# 37                 11434                 53  1.355959e+09                 154
# 38                  7830                 42  7.861818e+08                  94
#
#     ...  bpm key   mode danceability_%  valence_% energy_% acousticness_%  \
# 3   ...  170   A  Major             55         58       72             11
# 21  ...  123  F#  Major             69         82       76              6
# 33  ...   97   E  Major             64         51       63             12
# 37  ...   96   F  Major             75         57       68              9
# 38  ...   95   D  Major             60         48       79              0
#
#     instrumentalness_%  liveness_%  speechiness_%
# 3                    0          11             15
# 21                   0           6              3
# 33                   0          19              5
# 37                   0          13              6
# 38                   0          12              4
#
# [5 rows x 24 columns]

# %%
plt.scatter(ts_df['danceability_%'], ts_df['streams'])

# %% [markdown]
# #### Histogram

# %%
# histogram

# %% [markdown]
# #### Pie Chart

# %%
# pie chart
